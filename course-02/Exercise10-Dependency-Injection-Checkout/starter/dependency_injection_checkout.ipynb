# %% [markdown]
# ### Exercise: E-Commerce Checkout with Dependency Injection
#
# **Goal:**
# Implement a flexible e-commerce checkout system where multiple services (payment, shipping, notification) are injected into a `CheckoutService`. The system should allow swapping strategies without modifying the service.
#
# ---
#
# **Scenario:**
# A checkout involves:
# - **Payment** (CreditCard, PayPal, Bitcoin)
# - **Shipping** (Standard, Express)
# - **Notification** (Email, SMS)
#
# You need to inject all dependencies rather than creating them inside `CheckoutService`.
#
# ---
#
# **Steps:**
#
# 1. **Define Interfaces**:
#    - `PaymentStrategy` with `pay(amount)`
#    - `ShippingStrategy` with `ship(order_id)`
#    - `NotificationService` with `notify(message)`
#
# 2. **Implement Concrete Classes**:
#    - Payments: `CreditCardPayment`, `PayPalPayment`, `BitcoinPayment`
#    - Shipping: `StandardShipping`, `ExpressShipping`
#    - Notifications: `EmailNotification`, `SMSNotification`
#
# 3. **Implement `CheckoutService`**:
#    - Accept `payment`, `shipping`, and `notification` via constructor (**constructor injection**)
#    - Implement a `checkout(order_id, amount)` method that:
#      1. Processes payment
#      2. Ships the order
#      3. Sends a notification
#
# 4. **Verify runtime flexibility**:
#    - Swap any of the strategies at runtime without modifying `CheckoutService`.

# %%
from abc import ABC, abstractmethod

# Step 1: Interfaces
class PaymentStrategy(ABC):
    @abstractmethod
    def pay(self, amount):
        pass

class ShippingStrategy(ABC):
    @abstractmethod
    def ship(self, order_id):
        pass

class NotificationService(ABC):
    @abstractmethod
    def notify(self, message):
        pass

# Step 2: Concrete Implementations
class CreditCardPayment(PaymentStrategy):
    pass  # TODO: Implement pay()

class PayPalPayment(PaymentStrategy):
    pass  # TODO: Implement pay()

class StandardShipping(ShippingStrategy):
    pass  # TODO: Implement ship()

class ExpressShipping(ShippingStrategy):
    pass  # TODO: Implement ship()

class EmailNotification(NotificationService):
    pass  # TODO: Implement notify()

class SMSNotification(NotificationService):
    pass  # TODO: Implement notify()

# Step 3: Checkout Service
class CheckoutService:
    def __init__(self, payment: PaymentStrategy,
                 shipping: ShippingStrategy,
                 notification: NotificationService):
        # TODO: Store injected dependencies
        pass

    def checkout(self, order_id, amount):
        # TODO: Process payment, ship order, send notification
        pass

# %%
import unittest

class TestCheckoutDI(unittest.TestCase):
    def test_creditcard_standard_email(self):
        service = CheckoutService(
            payment=CreditCardPayment(),
            shipping=StandardShipping(),
            notification=EmailNotification()
        )
        self.assertEqual(
            service.checkout("ORDER123", 100),
            "Paid 100 using Credit Card | Shipped ORDER123 via Standard | Notified via Email"
        )

    def test_paypal_express_sms(self):
        service = CheckoutService(
            payment=PayPalPayment(),
            shipping=ExpressShipping(),
            notification=SMSNotification()
        )
        self.assertEqual(
            service.checkout("ORDER456", 200),
            "Paid 200 using PayPal | Shipped ORDER456 via Express | Notified via SMS"
        )


if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
